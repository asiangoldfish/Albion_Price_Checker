# %%
import pandas as pd

# %%
df = pd.read_json("data/items.json")
pd.set_option("max_colwidth", 50)

# %%
df
# Out:
#              LocalizationNameVariable       LocalizationDescriptionVariable                                     LocalizedNames                              LocalizedDescriptions  Index                UniqueName
# 0               @ITEMS_UNIQUE_HIDEOUT            @ITEMS_UNIQUE_HIDEOUT_DESC  {'EN-US': 'Hideout Construction Kit', 'DE-DE':...  {'EN-US': 'Hideout construction kits are used ...      1            UNIQUE_HIDEOUT
# 1          @ITEMS_T1_FARM_CARROT_SEED       @ITEMS_T1_FARM_CARROT_SEED_DESC  {'EN-US': 'Carrot Seeds', 'DE-DE': 'Möhrensame...  {'EN-US': 'Carrot Seeds are used to plant a pa...      2       T1_FARM_CARROT_SEED
# 2            @ITEMS_T2_FARM_BEAN_SEED         @ITEMS_T2_FARM_BEAN_SEED_DESC  {'EN-US': 'Bean Seeds', 'DE-DE': 'Bohnensamen'...  {'EN-US': 'Bean Seeds are used to plant a patc...      3         T2_FARM_BEAN_SEED
# ...
