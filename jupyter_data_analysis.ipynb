# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", 6)
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_json("data/items.json")

# %%
df
# Out:
#              LocalizationNameVariable       LocalizationDescriptionVariable  \
# 0               @ITEMS_UNIQUE_HIDEOUT            @ITEMS_UNIQUE_HIDEOUT_DESC
# 1          @ITEMS_T1_FARM_CARROT_SEED       @ITEMS_T1_FARM_CARROT_SEED_DESC
# 2            @ITEMS_T2_FARM_BEAN_SEED         @ITEMS_T2_FARM_BEAN_SEED_DESC
# 3           @ITEMS_T3_FARM_WHEAT_SEED        @ITEMS_T3_FARM_WHEAT_SEED_DESC
# 4          @ITEMS_T4_FARM_TURNIP_SEED       @ITEMS_T4_FARM_TURNIP_SEED_DESC
# ...                               ...                                   ...
# 7764   @ITEMS_T6_JOURNAL_FISHING_FULL   @ITEMS_T6_JOURNAL_FISHING_FULL_DESC
# 7765  @ITEMS_T7_JOURNAL_FISHING_EMPTY  @ITEMS_T7_JOURNAL_FISHING_EMPTY_DESC
# 7766   @ITEMS_T7_JOURNAL_FISHING_FULL   @ITEMS_T7_JOURNAL_FISHING_FULL_DESC
# 7767  @ITEMS_T8_JOURNAL_FISHING_EMPTY  @ITEMS_T8_JOURNAL_FISHING_EMPTY_DESC
# 7768   @ITEMS_T8_JOURNAL_FISHING_FULL   @ITEMS_T8_JOURNAL_FISHING_FULL_DESC
#
# ...

# %%
df.loc[df["UniqueName"] == "T5_2H_AXE"]
# Out:
#      LocalizationNameVariable LocalizationDescriptionVariable  \
# 6065         @ITEMS_T5_2H_AXE           @ITEMS_T5_2H_AXE_DESC
#
#                                                                                                                                                                                                                                                                      LocalizedNames  \
# 6065  {'EN-US': 'Expert's Greataxe', 'DE-DE': 'Großaxt des Experten', 'FR-FR': 'Grande hache de l'expert', 'RU-RU': 'Большой топор (эксперт)', 'PL-PL': 'Topór Znawcy', 'ES-ES': 'Gran hacha del experto', 'PT-BR': 'Machadão do Perito', 'ZH-CN': '专家级巨斧', 'KO-KR': '전문가의 그레이트액스'}
#
#                                                                                                                                                                                                                                           LocalizedDescriptions  \
# ...

# %%
pd.set_option("max_colwidth", None)
